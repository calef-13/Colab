# %% [markdown]
# <a href="https://colab.research.google.com/github/calef-13/Colab/blob/main/Laboratorio8junio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Laboratorio inicial de uso de Colab**

# %% [markdown]
# Abner López Briones

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
import pandas as pd

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc= gspread.authorize(creds)
sh= gc.create('Abner Lopez Briones')

# %%
worksheet = gc.open('Abner Lopez Briones').sheet1

cell_list = worksheet.range('A1:g14')

import random 
for cell in cell_list:
  cell.value = random.randint(1,10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1j5UDiVuudqFnhkIVrzLZB251nMLoARarrH_vzRarfhY',
#  'updatedCells': 98,
#  'updatedColumns': 7,
#  'updatedRange': "'Hoja 1'!A1:G14",
#  'updatedRows': 14}

# %%
worksheet = gc.open('Abner Lopez Briones').sheet1
rows=worksheet.get_all_values()
print(rows)
# Out:
# [['8', '4', '3', '1', '5', '3', '10'], ['6', '5', '3', '7', '1', '3', '5'], ['3', '8', '9', '8', '3', '2', '5'], ['5', '7', '1', '8', '9', '10', '4'], ['10', '7', '6', '8', '10', '7', '8'], ['4', '3', '9', '3', '6', '5', '4'], ['1', '9', '1', '10', '8', '10', '5'], ['10', '4', '9', '4', '10', '5', '9'], ['9', '3', '3', '4', '1', '9', '9'], ['5', '4', '10', '5', '8', '2', '1'], ['2', '9', '4', '1', '3', '3', '5'], ['7', '1', '3', '10', '10', '7', '3'], ['4', '6', '5', '6', '9', '4', '3'], ['5', '6', '6', '1', '10', '8', '8']]
